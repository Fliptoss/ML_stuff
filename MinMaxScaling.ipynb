# %% [markdown]
# <a href="https://colab.research.google.com/github/Fliptoss/ML_stuff/blob/main/MinMaxScaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/wine_data.csv', header=None, usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict = {1:'blue', 3:'red', 2:'green'}
sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'], hue=df['Class label'], palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1), df['Class label'], test_size=0.3, random_state=0)

# %%
X_train, X_test
# Out:
# (     Alcohol  Malic acid
#  22     13.71        1.86
#  108    12.22        1.29
#  175    13.27        4.28
#  145    13.16        3.57
#  71     13.86        1.51
#  ..       ...         ...
#  103    11.82        1.72
#  67     12.37        1.17
#  117    12.42        1.61
#  47     13.90        1.68
#  172    14.16        2.51
#
#  [124 rows x 2 columns],
#       Alcohol  Malic acid
#  54     13.74        1.67
#  151    12.79        2.67
#  63     12.37        1.13
#  55     13.56        1.73
#  123    13.05        5.80
#  121    11.56        2.05
#  7      14.06        2.15
#  160    12.36        3.83
#  106    12.25        1.73
#  90     12.08        1.83
#  141    13.36        2.56
#  146    13.88        5.04
#  5      14.20        1.76
#  98     12.37        1.07
#  168    13.58        2.58
#  80     12.00        0.92
#  33     13.76        1.53
#  18     14.19        1.59
#  61     12.64        1.36
#  51     13.83        1.65
#  66     13.11        1.01
# ...

# %%
X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(X_train)

X_train_scaler = scaler.transform(X_train)
X_test_scaler = scaler.transform(X_test)

# %%
X_train_scaler
# Out:
# array([[0.72043011, 0.20378151],
#        [0.31989247, 0.08403361],
#        [0.60215054, 0.71218487],
#        [0.57258065, 0.56302521],
#        [0.76075269, 0.1302521 ],
#        [0.48924731, 0.5       ],
#        [0.75537634, 0.67857143],
#        [0.61021505, 0.17436975],
#        [0.54301075, 0.62394958],
#        [0.39784946, 0.07352941],
#        [0.33870968, 0.1092437 ],
#        [0.46774194, 0.53361345],
#        [0.5188172 , 0.53781513],
#        [0.70967742, 0.07563025],
#        [0.57258065, 0.30882353],
#        [0.36021505, 0.0105042 ],
#        [0.38709677, 0.13235294],
#        [0.20967742, 0.25840336],
#        [0.59408602, 0.64915966],
#        [0.82526882, 0.26680672],
#        [0.15591398, 0.09663866],
#        [0.52688172, 0.16386555],
#        [0.46774194, 0.31512605],
#        [0.65860215, 0.16386555],
#        [0.1155914 , 0.5987395 ],
#        [0.27956989, 0.26680672],
#        [0.21236559, 0.12184874],
#        [0.65053763, 0.59033613],
# ...

# %%
X_train_scaler = pd.DataFrame(X_train_scaler, columns=X_train.columns)
X_test_scaler = pd.DataFrame(X_test_scaler, columns=X_test.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaler.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Alcohol'], X_train['Malic acid'], c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaler['Alcohol'], X_train_scaler['Malic acid'], c=y_train)
ax2.set_title("After Scaling")
# Out:
# Text(0.5, 1.0, 'After Scaling')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title("Before Scaling")
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)
ax2.set_title("After Scaling")
sns.kdeplot(X_train_scaler['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaler['Malic acid'], ax=ax2)
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Alcohol', ylabel='Density'>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

## alcohol
ax1.set_title("Alcohol before scaling")
sns.kdeplot(X_train['Alcohol'], ax=ax1)

ax1.set_title("Alcohol after scaling")
sns.kdeplot(X_train_scaler['Alcohol'], ax=ax2)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))

## alcohol
ax1.set_title("Malic Acid before scaling")
sns.kdeplot(X_train['Malic acid'], ax=ax1)

ax1.set_title("Malic Acid after scaling")
sns.kdeplot(X_train_scaler['Malic acid'], ax=ax2)
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>
